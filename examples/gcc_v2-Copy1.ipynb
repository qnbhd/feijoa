# %%
from gimeltune import load_job
from examples.gcc.runner_v2 import SPACE

# %%
job = load_job(SPACE, 'test_job_2037', 'test_job_2037')

# %%
job.dataframe
# Out:
#        id  job_id               state  \
# 0       1       1  ExperimentState.OK
# 1       2       1  ExperimentState.OK
# 2       3       1  ExperimentState.OK
# 3       4       1  ExperimentState.OK
# 4       5       1  ExperimentState.OK
# ..    ...     ...                 ...
# 995   996       1  ExperimentState.OK
# 996   997       1  ExperimentState.OK
# 997   998       1  ExperimentState.OK
# 998   999       1  ExperimentState.OK
# 999  1000       1  ExperimentState.OK
#
#                                                   hash  objective_result  \
# 0    b92115a6aafda189406c9a0443c6a4795c6fb35732fdda...            0.1150
# 1    0d2203db429428f7b14b0bdb8d68802e0c18aaa2dafb0a...            0.1400
# 2    34134e84c49199c1f0a57163a3d93d50abb60b82c92aed...            0.1420
# 3    59eca7fd5721b379c002e23ac964e473855307b12cc7f3...            0.1090
# 4    deed159666f153786e8b42dae6c217d02436a71477ad1c...            0.1380
# ..                                                 ...               ...
# 995  3ac1e2f8f2790c4baebd54174ab80320b2f86bc00190f3...            0.1035
# 996  1161ebe8dbee7cb7bcc728ad6d077467db14f0870190f3...            0.1035
# 997  76284d7cedc1990fbf26dcc67539ddb79a46e28c0190f3...            0.1035
# 998  021e82ad1ef52916122b8053f877c2e90bbd8a750190f3...            0.1035
# 999  a9da3672e50224ea0f9aff6d9786b041ea7fd3520190f3...            0.1035
#
#                   requestor                create_time  \
# 0    SkoptBayesianAlgorithm 2022-04-12 12:43:59.369789
# 1    SkoptBayesianAlgorithm 2022-04-12 12:44:03.226470
# 2    SkoptBayesianAlgorithm 2022-04-12 12:44:07.317823
# 3    SkoptBayesianAlgorithm 2022-04-12 12:44:11.457241
# 4    SkoptBayesianAlgorithm 2022-04-12 12:44:15.029961
# ..                      ...                        ...
# 995  SkoptBayesianAlgorithm 2022-04-12 17:48:41.674243
# 996  SkoptBayesianAlgorithm 2022-04-12 17:48:45.579688
# 997  SkoptBayesianAlgorithm 2022-04-12 17:48:49.471112
# 998  SkoptBayesianAlgorithm 2022-04-12 17:48:53.363214
# 999  SkoptBayesianAlgorithm 2022-04-12 17:48:57.257154
#
#                    finish_time   -O    align-functions  ...  \
# 0   2022-04-12 12:44:03.224277  -O3  -falign-functions  ...
# 1   2022-04-12 12:44:07.315544  -O1               None  ...
# 2   2022-04-12 12:44:11.454991  -O1  -falign-functions  ...
# 3   2022-04-12 12:44:15.027630  -O2               None  ...
# 4   2022-04-12 12:44:19.299565  -O1  -falign-functions  ...
# ..                         ...  ...                ...  ...
# 995 2022-04-12 17:48:45.249617  -O2               None  ...
# 996 2022-04-12 17:48:49.141149  -O2               None  ...
# 997 2022-04-12 17:48:53.033045  -O2               None  ...
# 998 2022-04-12 17:48:56.925937  -O2               None  ...
# 999 2022-04-12 17:49:00.814289  -O2               None  ...
#
#     early-inlining-insns gcse-cost-distance-ratio iv-max-considered-uses  \
# 0                    387                       38                    705
# 1                    362                       96                    970
# 2                    606                       37                    738
# 3                    366                       34                    241
# 4                     83                       34                    978
# ..                   ...                      ...                    ...
# 995                  908                       84                    209
# 996                  755                       88                     63
# 997                  727                        0                    398
# 998                  680                       13                    278
# 999                  954                       24                    549
#
#     compile_time    time     size       std        cv   low  high
# 0           0.93  0.1150  51088.0  0.065383  0.568552  0.10  0.40
# 1           0.76  0.1400  51576.0  0.043589  0.311350  0.13  0.33
# 2           0.77  0.1420  51576.0  0.052307  0.368358  0.13  0.37
# 3           0.83  0.1090  51088.0  0.039230  0.359909  0.10  0.28
# 4           0.86  0.1380  51576.0  0.013266  0.096134  0.13  0.19
# ..           ...     ...      ...       ...       ...   ...   ...
# 995         0.85  0.1035  50904.0  0.015256  0.147402  0.10  0.17
# 996         0.83  0.1035  50904.0  0.015256  0.147402  0.10  0.17
# 997         0.83  0.1035  50904.0  0.015256  0.147402  0.10  0.17
# 998         0.83  0.1035  50904.0  0.015256  0.147402  0.10  0.17
# 999         0.83  0.1035  50904.0  0.015256  0.147402  0.10  0.17
#
# [1000 rows x 25 columns]

# %%
ddf = pd.DataFrame(columns=['finish_time', 'objective_result', 'std'])

print(ddf)

minima = 1e100

for index, rows in df.iterrows():
    if rows['objective_result'] < minima:
        minima = rows['objective_result']
        ddf = ddf.append({'finish_time': rows['finish_time'],
             'objective_result': rows['objective_result'],
             'std': rows['std']}, ignore_index=True)
# Out:
# ╭──────────────────────────── Traceback (most recent call last) ────────────────────────────╮
# │                                                                                           │
# │ /var/folders/gp/1qc74rb50b9cp66q8cxshnwh0000gn/T/ipykernel_7074/3229743436.py:1 in <cell  │
# │ line: 1>                                                                                  │
# │                                                                                           │
# │ [Errno 2] No such file or directory:                                                      │
# │ '/var/folders/gp/1qc74rb50b9cp66q8cxshnwh0000gn/T/ipykernel_7074/3229743436.py'           │
# ╰───────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'pd' is not defined
